# %%
from settings import config
from pathlib import Path
OUTPUT_DIR = Path(config("OUTPUT_DIR"))
DATA_DIR = Path(config("DATA_DIR"))
WRDS_USERNAME = config("WRDS_USERNAME")
import pandas as pd
import wrds

# %%
db = wrds.Connection(wrds_username=WRDS_USERNAME)
# Out:
# Loading library list...
# Done

# %%
db.describe_table(library="tr_ds_fut", table="wrds_contract_info")
# Out:
# Approximately 434565 rows in tr_ds_fut.wrds_contract_info.
#                 name  nullable            type  \
# 0            futcode      True  NUMERIC(11, 0)
# 1          contrcode      True  NUMERIC(11, 0)
# 2            clscode      True  NUMERIC(11, 0)
# 3             dsmnem      True     VARCHAR(10)
# 4          contrname      True     VARCHAR(90)
# 5                ldb      True      VARCHAR(3)
# 6          contrdate      True     VARCHAR(12)
# 7       contrdatefmt      True      VARCHAR(8)
# 8        isocurrcode      True      VARCHAR(3)
# 9        isocurrdesc      True     VARCHAR(90)
# 10      currunitcode      True      VARCHAR(4)
# 11          unitcode      True  NUMERIC(11, 0)
# 12          unitdesc      True     VARCHAR(90)
# 13       trdstatcode      True      VARCHAR(1)
# 14         startdate      True            DATE
# 15       lasttrddate      True            DATE
# 16       sttlmntdate      True            DATE
# 17    expirationdate      True            DATE
# ...

# %%
query = """SELECT * FROM tr_ds_fut.wrds_contract_info WHERE contrname ILIKE '%%henry hub%%' AND contrdate LIKE '0125' LIMIT 1000"""
data = db.raw_sql(query)
data
# Out:
#     futcode  contrcode  clscode   dsmnem  \
# 0  354503.0     3888.0   2910.0  NHD0125
# 1  383627.0     3889.0   2911.0  NHF0125
# 2  283438.0     2030.0   3813.0  NHP0125
# 3  244376.0     2028.0   1513.0  NHN0125
#
#                                            contrname  ldb contrdate  \
# 0  Henry Hub Natural Gas Financial Last Day Compo...  COM      0125
# 1  Henry Hub Natural Gas Look-Alike Penultimate C...  COM      0125
# 2                                HENRY HUB PEN. SWAP  COM      0125
# 3                                 HENRY HUB GAS SWAP  COM      0125
#
#   contrdatefmt isocurrcode isocurrdesc  ...   startdate  lasttrddate  \
# 0         <NA>         USD   US Dollar  ...  2018-02-21   2024-12-27
# 1         <NA>         USD   US Dollar  ...  2019-11-22   2024-12-26
# 2         <NA>         USD   US Dollar  ...  2015-02-19   2024-12-26
# 3         <NA>         USD   US Dollar  ...  2013-05-10   2024-12-27
#
# ...

# %%
db.describe_table(library="tr_ds_fut", table="wrds_fut_contract")
# Out:
# Approximately 162185055 rows in tr_ds_fut.wrds_fut_contract.
#             name  nullable              type  \
# 0        futcode      True    NUMERIC(11, 0)
# 1          date_      True              DATE
# 2          open_      True  DOUBLE PRECISION
# 3           high      True  DOUBLE PRECISION
# 4            low      True  DOUBLE PRECISION
# 5         volume      True  DOUBLE PRECISION
# 6     settlement      True  DOUBLE PRECISION
# 7   openinterest      True  DOUBLE PRECISION
# 8              p      True  DOUBLE PRECISION
# 9             pb      True  DOUBLE PRECISION
# 10            pa      True  DOUBLE PRECISION
# 11            wa      True  DOUBLE PRECISION
# 12            ca      True  DOUBLE PRECISION
# 13            yd      True  DOUBLE PRECISION
# 14            hm      True  DOUBLE PRECISION
# 15            ha      True  DOUBLE PRECISION
# 16            mt      True  DOUBLE PRECISION
# 17            la      True  DOUBLE PRECISION
# ...

# %%
query = """SELECT * FROM tr_ds_fut.wrds_fut_contract WHERE futcode = 244376 LIMIT 10000"""
data = db.raw_sql(query)
data
# Out:
#        futcode       date_     open_      high       low  volume  settlement  \
# 0     244376.0  2013-05-10     6.867     6.867     6.867     0.0       6.867
# 1     244376.0  2013-05-13     6.877     6.877     6.877     0.0       6.877
# 2     244376.0  2013-05-14     6.908     6.908     6.908     0.0       6.908
# 3     244376.0  2013-05-15  6.889999  6.889999  6.889999     0.0    6.889999
# 4     244376.0  2013-05-16  6.886999  6.886999  6.886999     0.0    6.886999
# ...        ...         ...       ...       ...       ...     ...         ...
# 2926  244376.0  2024-12-20     3.748     3.748     3.748    80.0       3.748
# 2927  244376.0  2024-12-23     3.656     3.656     3.656     0.0       3.656
# 2928  244376.0  2024-12-24     3.946     3.946     3.946    65.0       3.946
# 2929  244376.0  2024-12-26     3.715     3.715     3.715   103.0       3.715
# 2930  244376.0  2024-12-27     3.514     3.514     3.514   124.0       3.514
#
# ...
