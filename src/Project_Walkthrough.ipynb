# %% [markdown]
# # Project Code and Data Walkthrough

# %% [markdown]
# ### Duncan Park and Kyle Parran
#
# #### This notebook intends to give users a brief tour of the data pulled, processed, and analyzed in our project.
#
#
#
# #

# %% [markdown]
# ## Import Statements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# local modules
import sys
sys.path.append('../src/')
from calc_format_futures_data import *
from pull_futures_data import *

import warnings
warnings.filterwarnings("ignore")
# Out:
# Loading library list...
# Done

# %% [markdown]
# ## Loading Data from WRDS
#
# #### First, for each commodity you try to find info on all the futures contracts for that respective commodity

# %%
info_df = fetch_wrds_contract_info(2036, 'paper')
info_df
# Out:
#       futcode  contrcode              contrname contrdate   startdate  \
# 0        46.0     2036.0  ORANGE JUICE (FCOJ-A)      0303  2001-10-08
# 1       189.0     2036.0  ORANGE JUICE (FCOJ-A)      0300  1998-09-08
# 2       190.0     2036.0  ORANGE JUICE (FCOJ-A)      0704  2002-12-03
# 3       391.0     2036.0  ORANGE JUICE (FCOJ-A)      0986  1985-04-01
# 4       912.0     2036.0  ORANGE JUICE (FCOJ-A)      0188  1986-08-01
# ..        ...        ...                    ...       ...         ...
# 201  318247.0     2036.0  ORANGE JUICE (FCOJ-A)      0978  1977-10-03
# 202  318248.0     2036.0  ORANGE JUICE (FCOJ-A)      1174  1973-12-03
# 203  318249.0     2036.0  ORANGE JUICE (FCOJ-A)      1175  1975-01-20
# 204  318250.0     2036.0  ORANGE JUICE (FCOJ-A)      1176  1975-12-01
# 205  318251.0     2036.0  ORANGE JUICE (FCOJ-A)      1177  1976-12-01
#
#     lasttrddate
# 0    2003-03-11
# 1    2000-03-13
# 2    2004-07-12
# 3    1986-09-17
# 4    1988-01-18
# ..          ...
# 201  1978-09-18
# 202  1974-11-15
# 203  1975-11-14
# 204  1976-11-16
# 205  1977-11-16
#
# [206 rows x 6 columns]

# %% [markdown]
# #### Then, for each commodity, we can query all the time series data for all of these relevant futures.

# %%
# we create a dictionary with the future codes as keys and their respective contract dates as values
futcodes_contrdates = info_df.set_index("futcode")["contrdate"].to_dict()
dict(list(futcodes_contrdates.items())[:5])
# Out:
# {46.0: '0303', 189.0: '0300', 190.0: '0704', 391.0: '0986', 912.0: '0188'}

# %%
# We query and fetch the time series data for the each of the future contracts
data_contracts = fetch_wrds_fut_contract(futcodes_contrdates, 'paper')
data_contracts
# Out:
#         futcode      date_  settlement contrdate
# 0          46.0 2001-10-08   93.250000      0303
# 1          46.0 2001-10-09   93.250000      0303
# 2          46.0 2001-10-10   93.549988      0303
# 3          46.0 2001-10-11   93.799988      0303
# 4          46.0 2001-10-12   98.799988      0303
# ...         ...        ...         ...       ...
# 72477  318251.0 1977-11-10  124.500000      1177
# 72478  318251.0 1977-11-11  125.500000      1177
# 72479  318251.0 1977-11-14  129.850000      1177
# 72480  318251.0 1977-11-15  131.100000      1177
# 72481  318251.0 1977-11-16  195.000000      1177
#
# [72482 rows x 4 columns]

# %% [markdown]
# #### We now make some transformations to the futures time series data to allow for later calculations

# %%
# Convert the data from daily observations to monthly observations by keeping only the last observation of each month (for each contract)
monthly_df = futures_series_to_monthly(data_contracts)

# %%
monthly_df
# Out:
#         futcode  settlement contr_period obs_period
# 69174  318238.0   50.099991      1974-07    1973-08
# 69193  318238.0   51.599991      1974-07    1973-09
# 69214  318238.0   58.099991      1974-07    1973-10
# 70372  318243.0   57.799988      1974-09    1973-10
# 69234  318238.0   58.799988      1974-07    1973-11
# ...         ...         ...          ...        ...
# 59641  197774.0  112.150000      2008-11    2008-08
# 51657  161827.0   94.199997      2008-09    2008-09
# 59662  197774.0   89.199997      2008-11    2008-09
# 59685  197774.0   76.199997      2008-11    2008-10
# 59690  197774.0   83.649994      2008-11    2008-11
#
# [3612 rows x 4 columns]

# %%
# create a new dataframe in which there is only one observation per month, and each observation has the first through 12th contract settlements (relative to observation month)
first_through_12th_contracts_df = extract_first_through_12th_contracts(monthly_df)

# %% [markdown]
# This is necessary, since for the basis calculation, we need the one-month futures price and the 12-month futures price. But, not all futures have all 12 months traded. Within the paper's methodology, if the one-month is not available, we need the nearest. If the 12-month is not available, we use the latest (up to 12 months).

# %%
first_through_12th_contracts_df.iloc[30:40]
# Out:
#          1mth_settlement  2mth_settlement  3mth_settlement  4mth_settlement  \
# 1976-02        61.449997              NaN        63.349991              NaN
# 1976-03              NaN        62.599991              NaN        64.349991
# 1976-04        59.449997              NaN        61.000000              NaN
# 1976-05              NaN        58.399994              NaN        59.199997
# 1976-06        53.000000              NaN        53.299988              NaN
# 1976-07              NaN        53.449997              NaN        54.799988
# 1976-08        48.000000              NaN        48.500000              NaN
# 1976-09              NaN        50.449997              NaN        51.399994
# 1976-10        47.599991              NaN        47.949997              NaN
# 1976-11              NaN        46.949997              NaN        47.849991
#
#          5mth_settlement  6mth_settlement  7mth_settlement  8mth_settlement  \
# 1976-02        65.099991              NaN        66.599991              NaN
# 1976-03              NaN        65.799988              NaN        66.849991
# 1976-04        62.500000              NaN        63.500000              NaN
# 1976-05              NaN        60.099991              NaN        60.949997
# 1976-06        54.299988              NaN        55.199997              NaN
# 1976-07              NaN        55.549988              NaN        56.549988
# 1976-08        49.750000              NaN        51.349991              NaN
# 1976-09              NaN        53.000000              NaN        54.399994
# 1976-10        49.099991              NaN        50.199997              NaN
# 1976-11              NaN        49.000000              NaN        50.000000
#
#          9mth_settlement  10mth_settlement  11mth_settlement  12mth_settlement
# 1976-02        67.750000               NaN         68.799988               NaN
# 1976-03              NaN         67.799988               NaN               NaN
# 1976-04        63.849991               NaN         64.899994               NaN
# 1976-05              NaN         61.899994               NaN               NaN
# 1976-06        56.099991               NaN         57.299988               NaN
# 1976-07              NaN         57.799988               NaN               NaN
# 1976-08        52.849991               NaN         54.250000               NaN
# 1976-09              NaN         55.649994               NaN               NaN
# 1976-10        51.399994               NaN         52.599991               NaN
# 1976-11              NaN         51.149994               NaN               NaN

# %% [markdown]
# #### Now, we calculate the statistics for the Table 1.
#
# We need to use the first_through_12th_contracts_df to calculate Basis, and the monthly_df to calculate the excess return statistics.
#
# The basis is defined as:
# $$ B_{i,t} = \frac{\log(F_{i,t,T_1}) - \log(F_{i,t,T_2})}{T_2 - T_1} $$
#
#
#
# where:
# - $ F_{i,t,T_1} $ is the one-month (or nearest) futures price ($ T_1 = 1 $)
# - $ F_{i,t,T_2} $ is the 12-month (or latest up to 12-months) futures price ($ T_2 = 12 $)
# - The basis is computed as the log difference between these prices, divided by the difference in maturity.

# %%
stats = compute_futures_stats(first_through_12th_contracts_df, monthly_df)

# %% [markdown]
# #### Key lines from this function:
# ``` python
# basis_df['basis'] = (np.log(basis_df['settlement_T1']) - np.log(basis_df['settlement_T2'])) / basis_df['month_diff'] * 100
#
# freq_bw = (basis_df["basis"] > 0).mean() * 100
#
# excess_return_df = monthly_df.groupby("futcode").apply(
#         lambda x: (x.sort_values(by="obs_period").iloc[-1]["settlement"] / x.sort_values(by="obs_period").iloc[0]["settlement"] - 1) * 100
#     ).reset_index(name="excess_return")

# %%
stats
# Out:
# {'N': 419,
#  'mean_basis': -0.308002088793494,
#  'freq_bw': 34.60620525059666,
#  'excess_return_mean': 4.1517311730356194,
#  'excess_return_std': 39.04106471572014,
#  'sharpe_ratio': 0.10634267285656013}

# %% [markdown]
# #### And we end up with our stats for one of our products!
# #### Now let's look at how we do this for several products at once

# %%
product_list = [3160, 289, 3161] # example product list
summary_table = pd.DataFrame() # we create an empty dataframe to store the summary statistics of each product
sector_map = { # example sector map
    3160: "Agriculture",
    289: "Agriculture",
    3161: "Agriculture"}

for code in product_list: # we iterate through each product in the list
    row = process_single_product(code, 'paper') # we process the product (do the operations and calculations shown above)
    if row is not None:
        row["Sector"] = sector_map.get(code, "")
        summary_table = pd.concat([summary_table, row], ignore_index=True) # we add the product row to the summary table

summary_table
# Out:
#         Commodity  Contract Code    N     Basis  Freq. of Backwardation (%)  \
# 0  WESTERN BARLEY         3160.0  277 -0.368168                   28.158845
# 1   BUTTER (CASH)          289.0   38 -0.222469                   15.789474
# 2          CANOLA         3161.0  342 -0.339598                   29.532164
#
#    E(Re) (Mean Annual Excess Return)  σ(Re) (Std Dev of Excess Return)  \
# 0                           5.231146                         28.549440
# 1                          -8.818858                         10.262846
# 2                           1.443846                         23.135137
#
#    Sharpe Ratio       Sector
# 0      0.183231  Agriculture
# 1     -0.859299  Agriculture
# 2      0.062409  Agriculture

# %% [markdown]
# #### Now let's create the table for all the products.
# #### In essence, let's culminate our best replication of Table 1 in Investment shocks and the Commodity Basis Spread by Fan Yang

# %%
# we create tables for either the time period used in the paper, or the largest time period possible currently
table_paper = main_summary(time_period="paper")
table_current = main_summary(time_period="current")

# %%
final_paper = final_table(table_paper)
final_current = final_table(table_current)

print("=== PAPER PERIOD ===")
display(final_paper)
print("\n=== CURRENT PERIOD ===")
display(final_current)
# Out:
# === PAPER PERIOD ===
# <style type="text/css">
# #T_cd962 table {
#   border-collapse: collapse;
#   border-top: 1px solid black;
#   border-bottom: 1px solid black;
# }
# #T_cd962 th {
#   background-color: #ffffff;
#   font-family: Cambria, serif;
#   font-size: 11pt;
#   font-weight: bold;
#   vertical-align: top;
#   line-height: 1.2;
#   padding: 4px;
#   border-bottom: 1px solid black;
# }
# #T_cd962 th.col6 {
#   font-weight: normal;
# }
# #T_cd962  th.col7 {
#   font-weight: normal;
# }
# #T_cd962 td {
#   font-family: 'Times New Roman', serif;
#   font-size: 11pt;
#   background-color: #ffffff;
#   border: 0px;
#   line-height: 1.2;
#   padding: 4px;
# }
# #T_cd962 .row_heading {
#   display: none;
# }
# #T_cd962  .blank {
#   display: none;
# }
# </style>
# <table id="T_cd962">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd962_level0_col0" class="col_heading level0 col0" >Sector</th>
#       <th id="T_cd962_level0_col1" class="col_heading level0 col1" >Commodity</th>
#       <th id="T_cd962_level0_col2" class="col_heading level0 col2" >Symbol</th>
#       <th id="T_cd962_level0_col3" class="col_heading level0 col3" >N</th>
#       <th id="T_cd962_level0_col4" class="col_heading level0 col4" >Basis</th>
#       <th id="T_cd962_level0_col5" class="col_heading level0 col5" >Freq. of<br>bw.</th>
#       <th id="T_cd962_level0_col6" class="col_heading level0 col6" >E[Re]</th>
#       <th id="T_cd962_level0_col7" class="col_heading level0 col7" >σ[Re]</th>
#       <th id="T_cd962_level0_col8" class="col_heading level0 col8" >Sharpe<br>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd962_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd962_row0_col0" class="data row0 col0" >Agriculture</td>
#       <td id="T_cd962_row0_col1" class="data row0 col1" >Barley</td>
#       <td id="T_cd962_row0_col2" class="data row0 col2" >WA</td>
#       <td id="T_cd962_row0_col3" class="data row0 col3" >277</td>
#       <td id="T_cd962_row0_col4" class="data row0 col4" >-0.37</td>
#       <td id="T_cd962_row0_col5" class="data row0 col5" >28.16</td>
#       <td id="T_cd962_row0_col6" class="data row0 col6" >5.23</td>
#       <td id="T_cd962_row0_col7" class="data row0 col7" >28.55</td>
#       <td id="T_cd962_row0_col8" class="data row0 col8" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd962_row1_col0" class="data row1 col0" ></td>
#       <td id="T_cd962_row1_col1" class="data row1 col1" >Butter</td>
#       <td id="T_cd962_row1_col2" class="data row1 col2" >02</td>
#       <td id="T_cd962_row1_col3" class="data row1 col3" >38</td>
#       <td id="T_cd962_row1_col4" class="data row1 col4" >-0.22</td>
#       <td id="T_cd962_row1_col5" class="data row1 col5" >15.79</td>
#       <td id="T_cd962_row1_col6" class="data row1 col6" >-8.82</td>
#       <td id="T_cd962_row1_col7" class="data row1 col7" >10.26</td>
#       <td id="T_cd962_row1_col8" class="data row1 col8" >-0.86</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd962_row2_col0" class="data row2 col0" ></td>
#       <td id="T_cd962_row2_col1" class="data row2 col1" >Canola</td>
#       <td id="T_cd962_row2_col2" class="data row2 col2" >WC</td>
#       <td id="T_cd962_row2_col3" class="data row2 col3" >342</td>
#       <td id="T_cd962_row2_col4" class="data row2 col4" >-0.34</td>
#       <td id="T_cd962_row2_col5" class="data row2 col5" >29.53</td>
#       <td id="T_cd962_row2_col6" class="data row2 col6" >1.44</td>
#       <td id="T_cd962_row2_col7" class="data row2 col7" >23.14</td>
#       <td id="T_cd962_row2_col8" class="data row2 col8" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd962_row3_col0" class="data row3 col0" ></td>
#       <td id="T_cd962_row3_col1" class="data row3 col1" >Cocoa</td>
#       <td id="T_cd962_row3_col2" class="data row3 col2" >CC</td>
#       <td id="T_cd962_row3_col3" class="data row3 col3" >418</td>
#       <td id="T_cd962_row3_col4" class="data row3 col4" >-0.24</td>
#       <td id="T_cd962_row3_col5" class="data row3 col5" >25.60</td>
#       <td id="T_cd962_row3_col6" class="data row3 col6" >3.67</td>
#       <td id="T_cd962_row3_col7" class="data row3 col7" >41.80</td>
#       <td id="T_cd962_row3_col8" class="data row3 col8" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cd962_row4_col0" class="data row4 col0" ></td>
#       <td id="T_cd962_row4_col1" class="data row4 col1" >Coffee</td>
#       <td id="T_cd962_row4_col2" class="data row4 col2" >KC</td>
#       <td id="T_cd962_row4_col3" class="data row4 col3" >364</td>
#       <td id="T_cd962_row4_col4" class="data row4 col4" >-0.33</td>
#       <td id="T_cd962_row4_col5" class="data row4 col5" >34.62</td>
#       <td id="T_cd962_row4_col6" class="data row4 col6" >3.87</td>
#       <td id="T_cd962_row4_col7" class="data row4 col7" >43.73</td>
#       <td id="T_cd962_row4_col8" class="data row4 col8" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cd962_row5_col0" class="data row5 col0" ></td>
#       <td id="T_cd962_row5_col1" class="data row5 col1" >Corn</td>
#       <td id="T_cd962_row5_col2" class="data row5 col2" >C-</td>
#       <td id="T_cd962_row5_col3" class="data row5 col3" >428</td>
#       <td id="T_cd962_row5_col4" class="data row5 col4" >-0.51</td>
#       <td id="T_cd962_row5_col5" class="data row5 col5" >23.13</td>
#       <td id="T_cd962_row5_col6" class="data row5 col6" >2.53</td>
#       <td id="T_cd962_row5_col7" class="data row5 col7" >31.57</td>
#       <td id="T_cd962_row5_col8" class="data row5 col8" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cd962_row6_col0" class="data row6 col0" ></td>
#       <td id="T_cd962_row6_col1" class="data row6 col1" >Cotton</td>
#       <td id="T_cd962_row6_col2" class="data row6 col2" >CT</td>
#       <td id="T_cd962_row6_col3" class="data row6 col3" >357</td>
#       <td id="T_cd962_row6_col4" class="data row6 col4" >-0.22</td>
#       <td id="T_cd962_row6_col5" class="data row6 col5" >33.05</td>
#       <td id="T_cd962_row6_col6" class="data row6 col6" >-0.89</td>
#       <td id="T_cd962_row6_col7" class="data row6 col7" >24.76</td>
#       <td id="T_cd962_row6_col8" class="data row6 col8" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cd962_row7_col0" class="data row7 col0" ></td>
#       <td id="T_cd962_row7_col1" class="data row7 col1" >Lumber</td>
#       <td id="T_cd962_row7_col2" class="data row7 col2" >LB</td>
#       <td id="T_cd962_row7_col3" class="data row7 col3" >365</td>
#       <td id="T_cd962_row7_col4" class="data row7 col4" >-0.50</td>
#       <td id="T_cd962_row7_col5" class="data row7 col5" >31.78</td>
#       <td id="T_cd962_row7_col6" class="data row7 col6" >-2.96</td>
#       <td id="T_cd962_row7_col7" class="data row7 col7" >25.74</td>
#       <td id="T_cd962_row7_col8" class="data row7 col8" >-0.12</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cd962_row8_col0" class="data row8 col0" ></td>
#       <td id="T_cd962_row8_col1" class="data row8 col1" >Oats</td>
#       <td id="T_cd962_row8_col2" class="data row8 col2" >O-</td>
#       <td id="T_cd962_row8_col3" class="data row8 col3" >356</td>
#       <td id="T_cd962_row8_col4" class="data row8 col4" >-0.55</td>
#       <td id="T_cd962_row8_col5" class="data row8 col5" >29.78</td>
#       <td id="T_cd962_row8_col6" class="data row8 col6" >4.26</td>
#       <td id="T_cd962_row8_col7" class="data row8 col7" >34.52</td>
#       <td id="T_cd962_row8_col8" class="data row8 col8" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_cd962_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cd962_row9_col0" class="data row9 col0" ></td>
#       <td id="T_cd962_row9_col1" class="data row9 col1" >O
# === CURRENT PERIOD ===
# <style type="text/css">
# #T_bac17 table {
#   border-collapse: collapse;
#   border-top: 1px solid black;
#   border-bottom: 1px solid black;
# }
# #T_bac17 th {
#   background-color: #ffffff;
#   font-family: Cambria, serif;
#   font-size: 11pt;
#   font-weight: bold;
#   vertical-align: top;
#   line-height: 1.2;
#   padding: 4px;
#   border-bottom: 1px solid black;
# }
# #T_bac17 th.col6 {
#   font-weight: normal;
# }
# #T_bac17  th.col7 {
#   font-weight: normal;
# }
# #T_bac17 td {
#   font-family: 'Times New Roman', serif;
#   font-size: 11pt;
#   background-color: #ffffff;
#   border: 0px;
#   line-height: 1.2;
#   padding: 4px;
# }
# #T_bac17 .row_heading {
#   display: none;
# }
# #T_bac17  .blank {
#   display: none;
# }
# </style>
# <table id="T_bac17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bac17_level0_col0" class="col_heading level0 col0" >Sector</th>
#       <th id="T_bac17_level0_col1" class="col_heading level0 col1" >Commodity</th>
#       <th id="T_bac17_level0_col2" class="col_heading level0 col2" >Symbol</th>
#       <th id="T_bac17_level0_col3" class="col_heading level0 col3" >N</th>
#       <th id="T_bac17_level0_col4" class="col_heading level0 col4" >Basis</th>
#       <th id="T_bac17_level0_col5" class="col_heading level0 col5" >Freq. of<br>bw.</th>
#       <th id="T_bac17_level0_col6" class="col_heading level0 col6" >E[Re]</th>
#       <th id="T_bac17_level0_col7" class="col_heading level0 col7" >σ[Re]</th>
#       <th id="T_bac17_level0_col8" class="col_heading level0 col8" >Sharpe<br>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bac17_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bac17_row0_col0" class="data row0 col0" >Agriculture</td>
#       <td id="T_bac17_row0_col1" class="data row0 col1" >Barley</td>
#       <td id="T_bac17_row0_col2" class="data row0 col2" >WA</td>
#       <td id="T_bac17_row0_col3" class="data row0 col3" >28</td>
#       <td id="T_bac17_row0_col4" class="data row0 col4" >0.01</td>
#       <td id="T_bac17_row0_col5" class="data row0 col5" >50.00</td>
#       <td id="T_bac17_row0_col6" class="data row0 col6" >31.71</td>
#       <td id="T_bac17_row0_col7" class="data row0 col7" >24.98</td>
#       <td id="T_bac17_row0_col8" class="data row0 col8" >1.27</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bac17_row1_col0" class="data row1 col0" ></td>
#       <td id="T_bac17_row1_col1" class="data row1 col1" >Butter</td>
#       <td id="T_bac17_row1_col2" class="data row1 col2" >02</td>
#       <td id="T_bac17_row1_col3" class="data row1 col3" >167</td>
#       <td id="T_bac17_row1_col4" class="data row1 col4" >0.34</td>
#       <td id="T_bac17_row1_col5" class="data row1 col5" >58.68</td>
#       <td id="T_bac17_row1_col6" class="data row1 col6" >16.02</td>
#       <td id="T_bac17_row1_col7" class="data row1 col7" >21.07</td>
#       <td id="T_bac17_row1_col8" class="data row1 col8" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bac17_row2_col0" class="data row2 col0" ></td>
#       <td id="T_bac17_row2_col1" class="data row2 col1" >Canola</td>
#       <td id="T_bac17_row2_col2" class="data row2 col2" >WC</td>
#       <td id="T_bac17_row2_col3" class="data row2 col3" >162</td>
#       <td id="T_bac17_row2_col4" class="data row2 col4" >0.15</td>
#       <td id="T_bac17_row2_col5" class="data row2 col5" >49.38</td>
#       <td id="T_bac17_row2_col6" class="data row2 col6" >22.36</td>
#       <td id="T_bac17_row2_col7" class="data row2 col7" >39.39</td>
#       <td id="T_bac17_row2_col8" class="data row2 col8" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bac17_row3_col0" class="data row3 col0" ></td>
#       <td id="T_bac17_row3_col1" class="data row3 col1" >Cocoa</td>
#       <td id="T_bac17_row3_col2" class="data row3 col2" >CC</td>
#       <td id="T_bac17_row3_col3" class="data row3 col3" >162</td>
#       <td id="T_bac17_row3_col4" class="data row3 col4" >-0.04</td>
#       <td id="T_bac17_row3_col5" class="data row3 col5" >41.98</td>
#       <td id="T_bac17_row3_col6" class="data row3 col6" >2.92</td>
#       <td id="T_bac17_row3_col7" class="data row3 col7" >22.86</td>
#       <td id="T_bac17_row3_col8" class="data row3 col8" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bac17_row4_col0" class="data row4 col0" ></td>
#       <td id="T_bac17_row4_col1" class="data row4 col1" >Coffee</td>
#       <td id="T_bac17_row4_col2" class="data row4 col2" >KC</td>
#       <td id="T_bac17_row4_col3" class="data row4 col3" >150</td>
#       <td id="T_bac17_row4_col4" class="data row4 col4" >-0.56</td>
#       <td id="T_bac17_row4_col5" class="data row4 col5" >14.00</td>
#       <td id="T_bac17_row4_col6" class="data row4 col6" >-5.80</td>
#       <td id="T_bac17_row4_col7" class="data row4 col7" >34.12</td>
#       <td id="T_bac17_row4_col8" class="data row4 col8" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bac17_row5_col0" class="data row5 col0" ></td>
#       <td id="T_bac17_row5_col1" class="data row5 col1" >Corn</td>
#       <td id="T_bac17_row5_col2" class="data row5 col2" >C-</td>
#       <td id="T_bac17_row5_col3" class="data row5 col3" >160</td>
#       <td id="T_bac17_row5_col4" class="data row5 col4" >0.02</td>
#       <td id="T_bac17_row5_col5" class="data row5 col5" >38.12</td>
#       <td id="T_bac17_row5_col6" class="data row5 col6" >9.58</td>
#       <td id="T_bac17_row5_col7" class="data row5 col7" >38.50</td>
#       <td id="T_bac17_row5_col8" class="data row5 col8" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bac17_row6_col0" class="data row6 col0" ></td>
#       <td id="T_bac17_row6_col1" class="data row6 col1" >Cotton</td>
#       <td id="T_bac17_row6_col2" class="data row6 col2" >CT</td>
#       <td id="T_bac17_row6_col3" class="data row6 col3" >151</td>
#       <td id="T_bac17_row6_col4" class="data row6 col4" >0.27</td>
#       <td id="T_bac17_row6_col5" class="data row6 col5" >55.63</td>
#       <td id="T_bac17_row6_col6" class="data row6 col6" >0.81</td>
#       <td id="T_bac17_row6_col7" class="data row6 col7" >24.02</td>
#       <td id="T_bac17_row6_col8" class="data row6 col8" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bac17_row7_col0" class="data row7 col0" ></td>
#       <td id="T_bac17_row7_col1" class="data row7 col1" >Lumber</td>
#       <td id="T_bac17_row7_col2" class="data row7 col2" >LB</td>
#       <td id="T_bac17_row7_col3" class="data row7 col3" >166</td>
#       <td id="T_bac17_row7_col4" class="data row7 col4" >-0.20</td>
#       <td id="T_bac17_row7_col5" class="data row7 col5" >30.72</td>
#       <td id="T_bac17_row7_col6" class="data row7 col6" >14.53</td>
#       <td id="T_bac17_row7_col7" class="data row7 col7" >60.94</td>
#       <td id="T_bac17_row7_col8" class="data row7 col8" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bac17_row8_col0" class="data row8 col0" ></td>
#       <td id="T_bac17_row8_col1" class="data row8 col1" >Oats</td>
#       <td id="T_bac17_row8_col2" class="data row8 col2" >O-</td>
#       <td id="T_bac17_row8_col3" class="data row8 col3" >63</td>
#       <td id="T_bac17_row8_col4" class="data row8 col4" >0.08</td>
#       <td id="T_bac17_row8_col5" class="data row8 col5" >39.68</td>
#       <td id="T_bac17_row8_col6" class="data row8 col6" >-4.32</td>
#       <td id="T_bac17_row8_col7" class="data row8 col7" >19.93</td>
#       <td id="T_bac17_row8_col8" class="data row8 col8" >-0.22</td>
#     </tr>
#     <tr>
#       <th id="T_bac17_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bac17_row9_col0" class="data row9 col0" ></td>
#       <td id="T_bac17_row9_col1" class="data row9 col1" >Orange
